# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Style setting**

# %%
sns.set(style="whitegrid")

# %% [markdown]
# # **Data Loading**

# %%
df = pd.read_csv("menu.csv")
print("Shape of dataset:", df.shape)
df.head()
# Out:
# Shape of dataset: (260, 24)
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
# ...

# %% [markdown]
# # **Data Overview**

# %% [markdown]
# **1.Basic info.**

# %%
print("\n--- Basic Info ---")
print(df.info())
# Out:
# --- Basic Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %% [markdown]
# **2.Statistical summary**

# %%
print("\n--- Statistical Summary ---")
print(df.describe())
# Out:
# --- Statistical Summary ---
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# # **Analysis of Nutrient**

# %% [markdown]
# **Distribution of calories**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Calories"], bins=30, color="blue")
plt.title("Calories Distribution")
plt.xlabel("Calories")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Highest Calorie Items**

# %%
top10_calories = df.nlargest(10, "Calories")[['Item','Category','Calories']]
print("\nTop 10 Highest Calorie Items:\n", top10_calories)
# Out:
# Top 10 Highest Calorie Items:
#                                                    Item            Category  \
# 82                        Chicken McNuggets (40 piece)      Chicken & Fish
# 32         Big Breakfast with Hotcakes (Large Biscuit)           Breakfast
# 31       Big Breakfast with Hotcakes (Regular Biscuit)           Breakfast
# 34   Big Breakfast with Hotcakes and Egg Whites (La...           Breakfast
# 33   Big Breakfast with Hotcakes and Egg Whites (Re...           Breakfast
# 81                        Chicken McNuggets (20 piece)      Chicken & Fish
# 253               McFlurry with M&M’s Candies (Medium)  Smoothies & Shakes
# 246                           Strawberry Shake (Large)  Smoothies & Shakes
# 249                            Chocolate Shake (Large)  Smoothies & Shakes
# 243                              Vanilla Shake (Large)  Smoothies & Shakes
#
#      Calories
# 82       1880
# 32       1150
# 31       1090
# 34       1050
# 33        990
# 81        940
# ...

# %% [markdown]
# **Highest Protein items**

# %%
top10_protein = df.nlargest(10, "Protein")[['Item','Category','Protein']]
print("\nTop 10 Highest Protein Items:\n", top10_protein)
# Out:
# Top 10 Highest Protein Items:
#                                               Item        Category  Protein
# 82                   Chicken McNuggets (40 piece)  Chicken & Fish       87
# 47             Double Quarter Pounder with Cheese     Beef & Pork       48
# 81                   Chicken McNuggets (20 piece)  Chicken & Fish       44
# 60          Premium Grilled Chicken Club Sandwich  Chicken & Fish       40
# 64       Bacon Clubhouse Grilled Chicken Sandwich  Chicken & Fish       40
# 51                         Bacon Clubhouse Burger     Beef & Pork       39
# 44            Quarter Pounder with Bacon & Cheese     Beef & Pork       37
# 45      Quarter Pounder with Bacon Habanero Ranch     Beef & Pork       37
# 31  Big Breakfast with Hotcakes (Regular Biscuit)       Breakfast       36
# 32    Big Breakfast with Hotcakes (Large Biscuit)       Breakfast       36

# %% [markdown]
# **Distribution by Category**

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="Category", y="Calories", data=df)
plt.title("Calorie Distribution by Category")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Nutritional values**

# %%
nutrient_cols = df.select_dtypes(include=['int64','float64']).columns
corr_matrix = df[nutrient_cols].corr()


plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Nutritional Values")
plt.show()

# %% [markdown]
# **Conclusion**

# %%
print("\nInsights:")
print("1. Categories like Beef & Pork tend to have the highest average calories.")
print("2. Chicken McNuggets (40 piece) is the top protein-heavy item (87g protein).")
print("3. Correlation shows Calories strongly linked with Fat & Carbs.")
# Out:
# Insights:
# 1. Categories like Beef & Pork tend to have the highest average calories.
# 2. Chicken McNuggets (40 piece) is the top protein-heavy item (87g protein).
# 3. Correlation shows Calories strongly linked with Fat & Carbs.
